# %% [markdown]
# ### Candidate Details DataFrame

# %%
from sre_parse import CATEGORY_NOT_DIGIT
import pandas as pd
import json
import os
def create_candidate_df(json_data,filename,candidate_id):
    row = {
        "candidate_id" : candidate_id,
        "filename": filename,            
        'full_name': json_data['basic_info']['full_name'],              
        'current_title': json_data['basic_info']['current_title'],          
        'email': json_data['contact_info']['email'],                  
        'phone': json_data['contact_info']['phone'],                  
        'city': json_data['contact_info']['address']['city'] if json_data['contact_info']['address'] else None,
        'country': json_data['contact_info']['address']['country'] if json_data['contact_info']['address'] else None,
        'linkedin': json_data['contact_info']['linkedin'],
        'github': json_data['contact_info']['github'],
        'summary': json_data['summary'],
        'total_skills': len(json_data['skills']) if json_data['skills'] is not None else 0,
        'total_experience_years': 0, 
        'education_level': 'Unknown',  
        'created_date': pd.Timestamp.now()
    }
    
    df = pd.DataFrame([row])
    return df
# Out:
# C:\Users\ahsan\AppData\Local\Temp\ipykernel_17376\1551355440.py:1: DeprecationWarning: module 'sre_parse' is deprecated
#   from sre_parse import CATEGORY_NOT_DIGIT

# %% [markdown]
# ### Skills DF

# %%
def create_skills(json_data,candidate_id):
    skills_data = []
    
    for skill in json_data['skills']:
        skill_row = {
            "candidate_id": candidate_id,
            "skill_name": skill["skill_name"],
            "proficiency": skill["proficiency"],
            "category": skill["category"],
            "years_of_experience": skill["years_of_experience"]
        }
        skills_data.append(skill_row)
    return pd.DataFrame(skills_data)

# %% [markdown]
# ### Experience DataFrame

# %%
def create_experience(json_data,candidate_id):
    experience_data = []
    for experience in json_data['experience']:
        experience_row = {
            "candidate_id": candidate_id,
            "job_title": experience["job_title"],
            "company": experience["company"],
            "start_date": experience["start_date"],
            "end_date": experience["end_date"],
            "employment_type": experience["employment_type"],
            "location": experience["location"],
            "is_current_job" : experience["end_date"] is None,
            "responsibilities_count": len(experience["responsibilities"]) if experience["responsibilities"] is not None else 0,
            "skills_used_count": len(experience["skills_used"]) if experience["skills_used"] is not None else 0,
        }
        experience_data.append(experience_row)
    return pd.DataFrame(experience_data)

# %% [markdown]
# ### Education DF

# %%
def create_education_df(json_data, candidate_id):
    education_data = []
    
    for edu in json_data['education']:
        edu_row = {
            'candidate_id': candidate_id,
            'degree': edu['degree'],
            'field': edu['field'],
            'institution': edu['institution'],
            'start_date': edu['start_date'],
            'end_date': edu['end_date'],
            'grade': edu['grade'],
            'location': edu['location'],
            'courses_count': len(edu['courses']) if edu['courses'] is not None else 0
        }
        education_data.append(edu_row)
    
    return pd.DataFrame(education_data)

# %%
def creating_table(file_path):
    files = os.listdir(file_path)
    index = 1
    
    candidate_df = pd.DataFrame()
    skills_df = pd.DataFrame()
    experience_df = pd.DataFrame()
    education_df = pd.DataFrame()
    
    for file in files:
        if file.endswith(".json"):
            with open(os.path.join(file_path,file),'r') as f:
                data = json.load(f)
            candidate_id = index
            filename = file
            current_candidate_df = create_candidate_df(data,filename,candidate_id)
            current_skills_df = create_skills(data,candidate_id)
            current_experience_df = create_experience(data,candidate_id)
            current_education_df = create_education_df(data,candidate_id)
            
            if index == 1:
                candidate_df = current_candidate_df
                skills_df = current_skills_df
                experience_df = current_experience_df
                education_df = current_education_df
            else:
                candidate_df = pd.concat([candidate_df, current_candidate_df], ignore_index=True)
                skills_df = pd.concat([skills_df, current_skills_df], ignore_index=True)
                experience_df = pd.concat([experience_df, current_experience_df], ignore_index=True)
                education_df = pd.concat([education_df, current_education_df], ignore_index=True)
            print(f"Processed resume {index}: {filename}")
            index += 1
    return candidate_df,skills_df,experience_df,education_df

# %%
basic,skills,experience,education = creating_table("../data/processed")
# Out:
# Processed resume 1: ADNAN AHMED - CV for Research Assistants - Lab Instructors.json
# Processed resume 2: Awais Anwar - CV for Lab Instructor.json
# Processed resume 3: Ebad Ali - CV for Research Assistant.json
# Processed resume 4: Faisal Nisar - CV for for Research Assistant.json
# Processed resume 5: Faisal Shahzad - CV for Lab Instructor.json
# Processed resume 6: Faizan Asghar - CV for Research Assistant - Lab Instructor.json
# Processed resume 7: Ghulam Jaffar - CV for Research Assistant.json
# Processed resume 8: Habib Ur Rahman - CV for Lab Instructor - Research Assistant.json
# Processed resume 9: Hafiz Ali Raja - CV for Lab Instructor.json
# Processed resume 10: Haris Ahmed - CV for Research Assistant.json
# Processed resume 11: Hitesh Kumar - Resume for Research Assistants - Lab Instructors.json
# Processed resume 12: Jawad Ahmed Bhutta - CV for Lab Instructor - Research Assistant.json
# Processed resume 13: Muhammad Azmi Umer - CV for Lab Instructor.json
# Processed resume 14: Muhammad Omaid Sheikh - CV for for Lab Instructor.json
# Processed resume 15: Muhammad Tayyab Yaqoob - CV for Lab Engineer.json
# Processed resume 16: SAAD HASSAN - CV for Research Assistants - Lab Instructors.json
# Processed resume 17: Saad Hassan Khan - CV for Research Assistant (1).json
# Processed resume 18: Sana Fatima - CV for Research Assistant.json
# Processed resume 19: Shawana Khan - CV for Lab Instructor (1).json
# Processed resume 20: Umair Ahmed - CV for Lab Instructor.json
# Processed resume 21: Urooj Sheikh - CV for Lab Engineer.json
# Processed resume 22: Waqas Ahmed - CV for Lab Instructor.json
# Processed resume 23: Zohaib Khan - CV for Research Assistant - Lab Instructor.json
# C:\Users\ahsan\AppData\Local\Temp\ipykernel_17376\2293205653.py:28: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   skills_df = pd.concat([skills_df, current_skills_df], ignore_index=True)
# C:\Users\ahsan\AppData\Local\Temp\ipykernel_17376\2293205653.py:28: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   skills_df = pd.concat([skills_df, current_skills_df], ignore_index=True)
# C:\Users\ahsan\AppData\Local\Temp\ipykernel_17376\2293205653.py:28: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   skills_df = pd.concat([skills_df, current_skills_df], ignore_index=True)

# %%
print(basic.info())
print(skills.info())
print(experience.info())
print(education.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23 entries, 0 to 22
# Data columns (total 15 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   candidate_id            23 non-null     int64
#  1   filename                23 non-null     object
#  2   full_name               23 non-null     object
#  3   current_title           18 non-null     object
#  4   email                   23 non-null     object
#  5   phone                   23 non-null     object
#  6   city                    22 non-null     object
#  7   country                 20 non-null     object
#  8   linkedin                8 non-null      object
#  9   github                  8 non-null      object
#  10  summary                 22 non-null     object
#  11  total_skills            23 non-null     int64
#  12  total_experience_years  23 non-null     int64
#  13  education_level         23 non-null     object
#  14  created_date            23 non-null     datetime64[ns]
# dtypes: datetime64[ns](1), int64(3), object(11)
# memory usage: 2.8+ KB
# None
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 222 entries, 0 to 221
# Data columns (total 5 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   candidate_id         222 non-null    int64
#  1   skill_name           222 non-null    object
#  2   proficiency          77 non-null     object
#  3   category             205 non-null    object
#  4   years_of_experience  41 non-null     float64
# dtypes: float64(1), int64(1), object(3)
# memory usage: 8.8+ KB
# None
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 49 entries, 0 to 48
# Data columns (total 10 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   candidate_id            49 non-null     int64
#  1   job_title               49 non-null     object
#  2   company                 48 non-null     object
#  3   start_date              35 non-null     object
#  4   end_date                28 non-null     object
#  5   employment_type         33 non-null     object
#  6   location                43 non-null     object
#  7   is_current_job          49 non-null     bool
#  8   responsibilities_count  49 non-null     int64
#  9   skills_used_count       49 non-null     int64
# dtypes: bool(1), int64(3), object(6)
# memory usage: 3.6+ KB
# None
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 73 entries, 0 to 72
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   candidate_id   73 non-null     int64
#  1   degree         73 non-null     object
#  2   field          63 non-null     object
#  3   institution    71 non-null     object
#  4   start_date     49 non-null     object
#  5   end_date       57 non-null     object
#  6   grade          46 non-null     object
#  7   location       62 non-null     object
#  8   courses_count  73 non-null     int64
# dtypes: int64(2), object(7)
# memory usage: 5.3+ KB
# None

# %%
basic
# Out:
#     candidate_id                                           filename  \
# 0              1  ADNAN AHMED - CV for Research Assistants - Lab...
# 1              2           Awais Anwar - CV for Lab Instructor.json
# 2              3          Ebad Ali - CV for Research Assistant.json
# 3              4  Faisal Nisar - CV for for Research Assistant.json
# 4              5        Faisal Shahzad - CV for Lab Instructor.json
# 5              6  Faizan Asghar - CV for Research Assistant - La...
# 6              7     Ghulam Jaffar - CV for Research Assistant.json
# 7              8  Habib Ur Rahman - CV for Lab Instructor - Rese...
# 8              9        Hafiz Ali Raja - CV for Lab Instructor.json
# 9             10       Haris Ahmed - CV for Research Assistant.json
# 10            11  Hitesh Kumar - Resume for Research Assistants ...
# 11            12  Jawad Ahmed Bhutta - CV for Lab Instructor - R...
# 12            13    Muhammad Azmi Umer - CV for Lab Instructor.json
# 13            14  Muhammad Omaid Sheikh - CV for for Lab Instruc...
# 14            15  Muhammad Tayyab Yaqoob - CV for Lab Engineer.json
# 15            16  SAAD HASSAN - CV for Research Assistants - Lab...
# 16            17  Saad Hassan Khan - CV for Research Assistant (...
# 17            18       Sana Fatima - CV for Research Assistant.json
# 18            19      Shawana Khan - CV for Lab Instructor (1).json
# 19            20           Umair Ahmed - CV for Lab Instructor.json
# 20            21            Urooj Sheikh - CV for Lab Engineer.json
# 21            22           Waqas Ahmed - CV for Lab Instructor.json
# 22            23  Zohaib Khan - CV for Research Assistant - Lab ...
#
#                        full_name  \
# 0                    ADNAN AHMED
# 1                    Awaiz Anwar
# 2                       Ebad Ali
# 3        Hafiz Muhammad Ali Raja
# 4                 Faisal Shahzad
# 5                  Faizan Asghar
# 6
# 7                Habib Ur Rahman
# 8        Hafiz Muhammad Ali Raja
# 9                    Haris Ahmed
# 10                HIT ESH KUMA R
# 11            Jawad Ahmed Bhutta
# 12            Muhammad Azmi Umer
# 13         MOHAMMAD UMAID SHEIKH
# 14  Engr. Muhammad Tayyab Yaqoob
# 15                   Saad Hassan
# 16              SAAD HASSAN KHAN
# 17                   SANA FATIMA
# 18                  SHAWANA KHAN
# 19                   Umair Ahmed
# 20                  UROOJ SHEIKH
# 21                   Waqas Ahmed
# 22                   Zohaib Khan
#
#                                       current_title  \
# 0
# 1
# 2
# 3                  Lab Assistant/ Network Assistant
# 4
# 5
# 6
# 7
# 8                  Lab Assistant/ Network Assistant
# 9                                              None
# 10
# 11
# 12                                             None
# 13
# 14                            Lecturer/LAB Engineer
# 15
# 16                                             None
# 17                                   Jr. Instructor
# 18                                             None
# 19                                             None
# 20                              Electrical Engineer
# 21                             Electronics Engineer
# 22  Research Assistant/ Lab Instructor (Interested)
#
#                            email                       phone        city  \
# 0             dani_a4a@yahoo.com           +92 (345) 8365922
# 1
# 2             ebadalie@gmail.com               +923022689940     Karachi
# 3    alisherhaidri1984@gmail.com               +923216839854  Bahawalpur
# 4      faisalkhan00668@yahoo.com                 03137144006    Sargodha
# 5   Faizanasghar_sm1@hotmail.com                 03462662309     Karachi
# 6      ghulamjaffar110@gmail.com             +92.344.8534083  Rawalpindi
# 7          Habib_tuf@hotmail.com               +923338967267     Sahiwal
# 8    alisherhaidri1984@gmail.com               +923216839854  Bahawalpur
# 9        Engrharris.iu@gmail.com          (+92-345) 278 1022     Karachi
# 10        hksolanki151@gmail.com             +92 332 3714436     Karachi
# 11            jabhutta@gmail.com             +92 333 3162772     Karachi
# 12    muhammadazmiumer@yahoo.com               +923312607116     Karachi
# 13            umaidned@gmail.com                0324 2748533     Karachi
# 14         bu_tayyab@hotmail.com             +92-321-2986106     Karachi
# 15          fadi_hitec@yahoo.com              +92342-1560619   Islamabad
# 16         Saadhassan@live.co.uk                 03364214764      QUETTA
# 17             fzee_03@yahoo.com                0334-3581384     Karachi
# 18      Shawana_khan24@yahoo.com                0345 8318343      QUETTA
# 19      Umair_ahmed403@yahoo.com                0332-2190191     Karachi
# 20    scorp_sheikh11@hotmail.com             +92 332 3453882        None
# 21            waqas638@gmail.com  +923455494026, 03125385028  Rawalpindi
# 22           me_zohaib@ymail.com              +92 3341251568     Karachi
#
#      country linkedin github  \
# 0
# 1   Pakistan
# 2   Pakistan     None   None
# 3   Pakistan     None   None
# 4       None
# 5   Pakistan
# 6   Pakistan     None   None
# 7   Pakistan
# 8   Pakistan     None   None
# 9   Pakistan     None   None
# 10  Pakistan     None   None
# 11  Pakistan
# 12  Pakistan     None   None
# 13  Pakistan     None   None
# 14  Pakistan
# 15  Pakistan
# 16  Pakistan     None   None
# 17  Pakistan     None   None
# 18  Pakistan     None   None
# 19      None     None   None
# 20      None     None   None
# 21  Pakistan     None   None
# 22  Pakistan     None   None
#
#                                               summary  total_skills  \
# 0   To join a dedicated and professional team in t...             7
# 1   Being a committed team player, want to be a pa...             4
# 2                                                None            10
# 3   To become a better & better IT resource with a...             6
# 4   I am young mature & enthusiastic individual be...            17
# 5   To acquire a career oriented position in a rep...             5
# 6   To seek a challenging and motivating career th...            16
# 7   To get the challenging position within the org...             6
# 8   To become a better & better IT resource with a...             6
# 9   Seeking a position in a Progressive and Reputa...             4
# 10  I’m an adaptable and efficient team player wit...             8
# 11  A well-presented, good all round performer who...            34
# 12  Looking for challenging and rewarding position...            12
# 13  Seeking full time opportunity to blend the the...            12
# 14                                                                7
# 15  To obtain a challenging position that allows m...            14
# 16  A position in a results-oriented organization ...             5
# 17  To utilize my skills for achieving the target ...            10
# 18  My aim is to get the better opportunities and ...            11
# 19  To use my knowledge and skills to better facil...             9
# 20  Seeking an Electrical Engineer position in pro...             5
# 21  A competent Electronics engineer with a compre...             7
# 22  Seeking challenging and pro-learning avenues w...             7
#
#     total_experience_years education_level               created_date
# 0                        0         Unknown 2025-07-26 06:15:32.320824
# 1                        0         Unknown 2025-07-26 06:15:32.323918
# 2                        0         Unknown 2025-07-26 06:15:32.327642
# 3                        0         Unknown 2025-07-26 06:15:32.331307
# 4                        0         Unknown 2025-07-26 06:15:32.336297
# 5                        0         Unknown 2025-07-26 06:15:32.339571
# 6                        0         Unknown 2025-07-26 06:15:32.341589
# 7                        0         Unknown 2025-07-26 06:15:32.341589
# 8                        0         Unknown 2025-07-26 06:15:32.351920
# 9                        0         Unknown 2025-07-26 06:15:32.358613
# 10                       0         Unknown 2025-07-26 06:15:32.358613
# 11                       0         Unknown 2025-07-26 06:15:32.358613
# 12                       0         Unknown 2025-07-26 06:15:32.366138
# 13                       0         Unknown 2025-07-26 06:15:32.366138
# 14                       0         Unknown 2025-07-26 06:15:32.374503
# 15                       0         Unknown 2025-07-26 06:15:32.379553
# 16                       0         Unknown 2025-07-26 06:15:32.382567
# 17                       0         Unknown 2025-07-26 06:15:32.382567
# 18                       0         Unknown 2025-07-26 06:15:32.382567
# 19                       0         Unknown 2025-07-26 06:15:32.390730
# 20                       0         Unknown 2025-07-26 06:15:32.390730
# 21                       0         Unknown 2025-07-26 06:15:32.390730
# 22                       0         Unknown 2025-07-26 06:15:32.390730

# %% [markdown]
# #### Analysis:
#
# Row 6 has no name
# 15+ Ppl have empty current title
# phone format inconsistency
# some candidates have missing city fields
#
# will now do extensive cleaning

# %%
import numpy as np
from datetime import datetime
import re

#Fixing empty names

def fix_empty_names(filename):
    name = filename.replace(".json","").replace(' - CV for Research Assistant', '').replace('Research Assistant','').replace(' - CV for Lab Instructor', '').replace(' - CV', '')
    return name.strip()


mask = (basic['full_name'].isna()) | (basic['full_name'] == "")
basic.loc[mask,'full_name'] = basic.loc[mask,'filename'].apply(fix_empty_names)

# %%
#Standardizing phone numbers

def clean_phone(phone):
    if pd.isna(phone) or phone == "":
        return None
    cleaned = re.sub(r'[^\d+]', '', str(phone))
    if cleaned.startswith('92') and not cleaned.startswith('+92'):
        cleaned = '+' + cleaned
    elif cleaned.startswith('0'):
        cleaned = '+92' + cleaned[1:]
    return cleaned

basic['phone'] = basic['phone'].apply(clean_phone)

# %%
#Standardizing cities

def clean_city(city):
    if pd.isna(city) or city == "":
        return None
    return city.strip().title()

basic['city'] = basic['city'].apply(clean_city)

# %% [markdown]
# ### Giving each profile a profile completeness score

# %%
important_fields = ['full_name','email','phone','current_title']

basic['completeness_score'] = basic[important_fields].notna().sum(axis=1) * 25

basic
# Out:
#     candidate_id                                           filename  \
# 0              1  ADNAN AHMED - CV for Research Assistants - Lab...
# 1              2           Awais Anwar - CV for Lab Instructor.json
# 2              3          Ebad Ali - CV for Research Assistant.json
# 3              4  Faisal Nisar - CV for for Research Assistant.json
# 4              5        Faisal Shahzad - CV for Lab Instructor.json
# 5              6  Faizan Asghar - CV for Research Assistant - La...
# 6              7     Ghulam Jaffar - CV for Research Assistant.json
# 7              8  Habib Ur Rahman - CV for Lab Instructor - Rese...
# 8              9        Hafiz Ali Raja - CV for Lab Instructor.json
# 9             10       Haris Ahmed - CV for Research Assistant.json
# 10            11  Hitesh Kumar - Resume for Research Assistants ...
# 11            12  Jawad Ahmed Bhutta - CV for Lab Instructor - R...
# 12            13    Muhammad Azmi Umer - CV for Lab Instructor.json
# 13            14  Muhammad Omaid Sheikh - CV for for Lab Instruc...
# 14            15  Muhammad Tayyab Yaqoob - CV for Lab Engineer.json
# 15            16  SAAD HASSAN - CV for Research Assistants - Lab...
# 16            17  Saad Hassan Khan - CV for Research Assistant (...
# 17            18       Sana Fatima - CV for Research Assistant.json
# 18            19      Shawana Khan - CV for Lab Instructor (1).json
# 19            20           Umair Ahmed - CV for Lab Instructor.json
# 20            21            Urooj Sheikh - CV for Lab Engineer.json
# 21            22           Waqas Ahmed - CV for Lab Instructor.json
# 22            23  Zohaib Khan - CV for Research Assistant - Lab ...
#
#                            full_name  \
# 0                        ADNAN AHMED
# 1                        Awaiz Anwar
# 2                           Ebad Ali
# 3            Hafiz Muhammad Ali Raja
# 4                     Faisal Shahzad
# 5                      Faizan Asghar
# 6   Ghulam Jaffar Research Assistant
# 7                    Habib Ur Rahman
# 8            Hafiz Muhammad Ali Raja
# 9                        Haris Ahmed
# 10                    HIT ESH KUMA R
# 11                Jawad Ahmed Bhutta
# 12                Muhammad Azmi Umer
# 13             MOHAMMAD UMAID SHEIKH
# 14      Engr. Muhammad Tayyab Yaqoob
# 15                       Saad Hassan
# 16                  SAAD HASSAN KHAN
# 17                       SANA FATIMA
# 18                      SHAWANA KHAN
# 19                       Umair Ahmed
# 20                      UROOJ SHEIKH
# 21                       Waqas Ahmed
# 22                       Zohaib Khan
#
#                                       current_title  \
# 0
# 1
# 2
# 3                  Lab Assistant/ Network Assistant
# 4
# 5
# 6
# 7
# 8                  Lab Assistant/ Network Assistant
# 9                                              None
# 10
# 11
# 12                                             None
# 13
# 14                            Lecturer/LAB Engineer
# 15
# 16                                             None
# 17                                   Jr. Instructor
# 18                                             None
# 19                                             None
# 20                              Electrical Engineer
# 21                             Electronics Engineer
# 22  Research Assistant/ Lab Instructor (Interested)
#
#                            email                     phone        city  \
# 0             dani_a4a@yahoo.com             +923458365922        None
# 1                                                     None        None
# 2             ebadalie@gmail.com             +923022689940     Karachi
# 3    alisherhaidri1984@gmail.com             +923216839854  Bahawalpur
# 4      faisalkhan00668@yahoo.com             +923137144006    Sargodha
# 5   Faizanasghar_sm1@hotmail.com             +923462662309     Karachi
# 6      ghulamjaffar110@gmail.com             +923448534083  Rawalpindi
# 7          Habib_tuf@hotmail.com             +923338967267     Sahiwal
# 8    alisherhaidri1984@gmail.com             +923216839854  Bahawalpur
# 9        Engrharris.iu@gmail.com             +923452781022     Karachi
# 10        hksolanki151@gmail.com             +923323714436     Karachi
# 11            jabhutta@gmail.com             +923333162772     Karachi
# 12    muhammadazmiumer@yahoo.com             +923312607116     Karachi
# 13            umaidned@gmail.com             +923242748533     Karachi
# 14         bu_tayyab@hotmail.com             +923212986106     Karachi
# 15          fadi_hitec@yahoo.com             +923421560619   Islamabad
# 16         Saadhassan@live.co.uk             +923364214764      Quetta
# 17             fzee_03@yahoo.com             +923343581384     Karachi
# 18      Shawana_khan24@yahoo.com             +923458318343      Quetta
# 19      Umair_ahmed403@yahoo.com             +923322190191     Karachi
# 20    scorp_sheikh11@hotmail.com             +923323453882        None
# 21            waqas638@gmail.com  +92345549402603125385028  Rawalpindi
# 22           me_zohaib@ymail.com             +923341251568     Karachi
#
#      country linkedin github  \
# 0
# 1   Pakistan
# 2   Pakistan     None   None
# 3   Pakistan     None   None
# 4       None
# 5   Pakistan
# 6   Pakistan     None   None
# 7   Pakistan
# 8   Pakistan     None   None
# 9   Pakistan     None   None
# 10  Pakistan     None   None
# 11  Pakistan
# 12  Pakistan     None   None
# 13  Pakistan     None   None
# 14  Pakistan
# 15  Pakistan
# 16  Pakistan     None   None
# 17  Pakistan     None   None
# 18  Pakistan     None   None
# 19      None     None   None
# 20      None     None   None
# 21  Pakistan     None   None
# 22  Pakistan     None   None
#
#                                               summary  total_skills  \
# 0   To join a dedicated and professional team in t...             7
# 1   Being a committed team player, want to be a pa...             4
# 2                                                None            10
# 3   To become a better & better IT resource with a...             6
# 4   I am young mature & enthusiastic individual be...            17
# 5   To acquire a career oriented position in a rep...             5
# 6   To seek a challenging and motivating career th...            16
# 7   To get the challenging position within the org...             6
# 8   To become a better & better IT resource with a...             6
# 9   Seeking a position in a Progressive and Reputa...             4
# 10  I’m an adaptable and efficient team player wit...             8
# 11  A well-presented, good all round performer who...            34
# 12  Looking for challenging and rewarding position...            12
# 13  Seeking full time opportunity to blend the the...            12
# 14                                                                7
# 15  To obtain a challenging position that allows m...            14
# 16  A position in a results-oriented organization ...             5
# 17  To utilize my skills for achieving the target ...            10
# 18  My aim is to get the better opportunities and ...            11
# 19  To use my knowledge and skills to better facil...             9
# 20  Seeking an Electrical Engineer position in pro...             5
# 21  A competent Electronics engineer with a compre...             7
# 22  Seeking challenging and pro-learning avenues w...             7
#
#     total_experience_years education_level               created_date  \
# 0                        0         Unknown 2025-07-26 06:15:32.320824
# 1                        0         Unknown 2025-07-26 06:15:32.323918
# 2                        0         Unknown 2025-07-26 06:15:32.327642
# 3                        0         Unknown 2025-07-26 06:15:32.331307
# 4                        0         Unknown 2025-07-26 06:15:32.336297
# 5                        0         Unknown 2025-07-26 06:15:32.339571
# 6                        0         Unknown 2025-07-26 06:15:32.341589
# 7                        0         Unknown 2025-07-26 06:15:32.341589
# 8                        0         Unknown 2025-07-26 06:15:32.351920
# 9                        0         Unknown 2025-07-26 06:15:32.358613
# 10                       0         Unknown 2025-07-26 06:15:32.358613
# 11                       0         Unknown 2025-07-26 06:15:32.358613
# 12                       0         Unknown 2025-07-26 06:15:32.366138
# 13                       0         Unknown 2025-07-26 06:15:32.366138
# 14                       0         Unknown 2025-07-26 06:15:32.374503
# 15                       0         Unknown 2025-07-26 06:15:32.379553
# 16                       0         Unknown 2025-07-26 06:15:32.382567
# 17                       0         Unknown 2025-07-26 06:15:32.382567
# 18                       0         Unknown 2025-07-26 06:15:32.382567
# 19                       0         Unknown 2025-07-26 06:15:32.390730
# 20                       0         Unknown 2025-07-26 06:15:32.390730
# 21                       0         Unknown 2025-07-26 06:15:32.390730
# 22                       0         Unknown 2025-07-26 06:15:32.390730
#
#     completeness_score
# 0                  100
# 1                   75
# 2                  100
# 3                  100
# 4                  100
# 5                  100
# 6                  100
# 7                  100
# 8                  100
# 9                   75
# 10                 100
# 11                 100
# 12                  75
# 13                 100
# 14                 100
# 15                 100
# 16                  75
# 17                 100
# 18                  75
# 19                  75
# 20                 100
# 21                 100
# 22                 100

# %% [markdown]
# #### Transforming Skills DataFrame

# %%
skills
# Out:
#      candidate_id                                         skill_name  \
# 0               1                                Anritsu Site Master
# 1               1                       Huwaie DBS_3900 and BTS-3900
# 2               1                               Commissioning of BTS
# 3               1               3D Simulation and Design of Antennas
# 4               1  Microsoft Word, Excel, PowerPoint, Access, InPage
# ..            ...                                                ...
# 217            23                              Programming Languages
# 218            23                                 Database Knowledge
# 219            23                                     Web technology
# 220            23                                           Software
# 221            23                                            English
#
#             proficiency   category  years_of_experience
# 0                  None  Technical                  NaN
# 1    profound knowledge  Technical                  NaN
# 2                  None  Technical                  NaN
# 3                  None  Technical                  NaN
# 4                  None   Software                  NaN
# ..                  ...        ...                  ...
# 217                None  Technical                  NaN
# 218                None  Technical                  NaN
# 219                None  Technical                  NaN
# 220                None  Technical                  NaN
# 221   working knowledge   Language                  NaN
#
# [222 rows x 5 columns]

# %%
def split_skills(skill_name):
    if ',' in skill_name:
        return [s.strip() for s in skill_name.split(',')]
    return [skill_name]

#now creating new rows for split skills
new_skills = []
for idx, row in skills.iterrows():
    skill_list = split_skills(row['skill_name'])
    for skill in skill_list:
        new_row = row.copy()
        new_row['skill_name'] = skill
        new_skills.append(new_row)
        
        
skills_cleaned = pd.DataFrame(new_skills)
skills_cleaned.tail(20)
# Out:
#      candidate_id                   skill_name        proficiency  \
# 202            20                        Email               None
# 203            21                       MATLAB             medium
# 204            21                         ETAP              basic
# 205            21                      Minitab              basic
# 206            21             CALCULUX /DIALUX             medium
# 207            21                    MS Office               None
# 208            22               Circuit Design               None
# 209            22  Microcontroller Programming               None
# 210            22                     Software               None
# 211            22              PLC Programming               None
# 212            22            Power Electronics               None
# 213            22             Embedded Systems               None
# 214            22              Control Systems               None
# 215            23     Computer and math skills               None
# 216            23            Operating Systems               None
# 217            23        Programming Languages               None
# 218            23           Database Knowledge               None
# 219            23               Web technology               None
# 220            23                     Software               None
# 221            23                      English  working knowledge
#
#                    category  years_of_experience
# 202                Internet                  NaN
# 203               Technical                  NaN
# 204               Technical                  NaN
# 205               Technical                  NaN
# 206               Technical                  NaN
# 207               Technical                  NaN
# 208  Electrical Engineering                  NaN
# 209  Electrical Engineering                  NaN
# 210  Electrical Engineering                  NaN
# 211  Electrical Engineering                  NaN
# 212  Electrical Engineering                  NaN
# 213  Electrical Engineering                  NaN
# 214  Electrical Engineering                  NaN
# 215               Technical                  NaN
# 216               Technical                  NaN
# 217               Technical                  NaN
# 218               Technical                  NaN
# 219               Technical                  NaN
# 220               Technical                  NaN
# 221                Language                  NaN

# %%
#skill mappings

skill_mapping = {
        'Microsoft Word': 'MS Word',
        'Microsoft Excel': 'MS Excel', 
        'Microsoft PowerPoint': 'MS PowerPoint',
        'Microsoft Access': 'MS Access',
}

skills_cleaned['skill_name'] = skills_cleaned['skill_name'].map(skill_mapping).fillna(skills_cleaned['skill_name'])

# %%
#Categorizing skills

def categorize_skills(skill_name):
    skill_lower = skill_name.lower()
    if any(lang in skill_lower for lang in ['python','java','c++','c#','javascript']):
        return 'Programming Language'
    elif any(db in skill_lower for db in ['sql','mysql','database']):
            return 'Database'
    elif any(ms in skill_lower for ms in ['word','excel','powerpoint','access']):
        return 'Office Tools'
    elif 'unity' in skill_lower:
        return 'Game Development'
    elif any(web in skill_lower for web in ['asp.net','react','node.js']):
        return 'Web Development'
    else:
        return 'Technical'
    
skills_cleaned['category'] = skills_cleaned['skill_name'].apply(categorize_skills)

skills_cleaned
# Out:
#      candidate_id                            skill_name         proficiency  \
# 0               1                   Anritsu Site Master                None
# 1               1          Huwaie DBS_3900 and BTS-3900  profound knowledge
# 2               1                  Commissioning of BTS                None
# 3               1  3D Simulation and Design of Antennas                None
# 4               1                               MS Word                None
# ..            ...                                   ...                 ...
# 217            23                 Programming Languages                None
# 218            23                    Database Knowledge                None
# 219            23                        Web technology                None
# 220            23                              Software                None
# 221            23                               English   working knowledge
#
#          category  years_of_experience
# 0       Technical                  NaN
# 1       Technical                  NaN
# 2       Technical                  NaN
# 3       Technical                  NaN
# 4    Office Tools                  NaN
# ..            ...                  ...
# 217     Technical                  NaN
# 218      Database                  NaN
# 219     Technical                  NaN
# 220     Technical                  NaN
# 221     Technical                  NaN
#
# [268 rows x 5 columns]

# %% [markdown]
# #### Cleaning experience DF

# %%
experience['start_date'] = pd.to_datetime(experience['start_date'],errors='coerce')
experience['end_date'] = pd.to_datetime(experience['end_date'],errors = 'coerce')

# %%
def calculate_duration(start,end):
    if pd.isna(start):
        return None
    end_date = end if not pd.isna(end) else pd.Timestamp.now()
    duration = (end_date - start).days/365.25
    return round(duration,2)

experience['duration_yrs'] = experience.apply(lambda x:calculate_duration(x['start_date'],x['end_date']),axis=1)

experience.head(5)
# Out:
#    candidate_id                         job_title  \
# 0             2                            Intern
# 1             3          Junior Android Developer
# 2             3                          Internee
# 3             4  Lab Assistant/ Network Assistant
# 4             4                    Lab Supervisor
#
#                                              company start_date   end_date  \
# 0                                          TECHLOGIX 2012-07-23 2012-08-31
# 1                       Salsoft Technologies Pvt.Ltd 2013-01-01 2013-12-31
# 2                                PIA-Computer Center 2013-01-01 2013-12-31
# 3                             Air University, Multan        NaT        NaT
# 4  COMSATS Institute of Information Technology, S...        NaT        NaT
#
#   employment_type  location  is_current_job  responsibilities_count  \
# 0      Internship                     False                       1
# 1       Full-time  Pakistan           False                       1
# 2      Internship  Pakistan           False                       2
# 3       Full-time    Multan            True                       0
# 4       Full-time   Sahiwal            True                       0
#
#    skills_used_count  duration_yrs
# 0                  0          0.11
# 1                  1          1.00
# 2                  1          1.00
# 3                  0           NaN
# 4                  0           NaN

# %%
employment_mapping = {
        'Full-time': 'Full-time',
        'Part-time': 'Part-time', 
        'Internship': 'Internship',
        'Intern': 'Internship',
        'Current': 'Full-time',
        'Program': 'Internship',
        None: 'Unknown'
    }

experience['employment_type'] = experience['employment_type'].map(employment_mapping).fillna('Unknown')

def clean_company(company):
    if pd.isna(company) or company == "":
        return 'Unknown'
    return company.strip()

experience['company'] = experience['company'].apply(clean_company)

# %% [markdown]
# #### Cleaning education df

# %%
education
# Out:
#     candidate_id                   degree                          field  \
# 0              1                      B.E  Telecommunication Engineering
# 1              1                    F.Sc.                Pre Engineering
# 2              1            Matriculation
# 3              2                   B. Sc.    Computer System Engineering
# 4              2                   F. Sc.                Pre-Engineering
# ..           ...                      ...                            ...
# 68            22       D.A.E (Electrical)                     Electrical
# 69            22  Matriculation (Science)                        Science
# 70            23                 Bachelor               Computer Science
# 71            23             Intermediate                Pre-Engineering
# 72            23                   Matric                        Science
#
#                                           institution  start_date    end_date  \
# 0                         Hamdard University, Karachi  2010-01-01  2014-12-31
# 1                 Tameer-e-Nau Public College, Quetta  2008-01-01  2009-12-31
# 2      Government high School  Killi Sheikhan, Quetta  2006-01-01  2007-12-31
# 3        The Islamia University, Bahawalpur, Pakistan  2010-01-01  2014-12-31
# 4            Superior College, Muzaffargarh, Pakistan  2006-08-01  2009-10-31
# ..                                                ...         ...         ...
# 68                Punjab Board of Technical Education  2007-01-01  2009-12-31
# 69                                   Rawalpindi Board  2003-01-01  2006-12-31
# 70  Federal Urdu University of Arts, Science and T...  2012-01-01  2016-12-31
# 71               F.G Boys Inter College Karachi Cantt  2009-01-01  2011-12-31
# 72     Ever Shine Govt. Boys Secondary School Karachi  2007-01-01  2009-12-31
#
#             grade                location  courses_count
# 0             3.1                 Karachi              0
# 1             74%                  Quetta              0
# 2             75%                  Quetta              0
# 3   CGPA 3.50/4.0    Bahawalpur, Pakistan              0
# 4      %AGE 76.00  Muzaffargarh, Pakistan              0
# ..            ...                     ...            ...
# 68           None                    None              0
# 69           None              Rawalpindi              0
# 70       3.79/4.0       Karachi, Pakistan             10
# 71           None       Karachi, Pakistan              0
# 72           None       Karachi, Pakistan              0
#
# [73 rows x 9 columns]

# %%
degree_mapping = {
        'B.E': 'Bachelor',
        'B. Sc.': 'Bachelor', 
        'Bachelor': 'Bachelor',
        'MS': 'Master',
        'Master': 'Master',
        'Masters': 'Master',
        'PhD': 'PhD',
        'Ph.D': 'PhD',
        'F.Sc.': 'Intermediate',
        'F. Sc.': 'Intermediate',
        'Intermediate': 'Intermediate',
        'Matriculation': 'Matric',
        'Matric': 'Matric',
        'D.A.E': 'Diploma'
    }

education['degree'] = education['degree'].map(degree_mapping).fillna(education['degree'])

education
# Out:
#     candidate_id                   degree                          field  \
# 0              1                 Bachelor  Telecommunication Engineering
# 1              1             Intermediate                Pre Engineering
# 2              1                   Matric
# 3              2                 Bachelor    Computer System Engineering
# 4              2             Intermediate                Pre-Engineering
# ..           ...                      ...                            ...
# 68            22       D.A.E (Electrical)                     Electrical
# 69            22  Matriculation (Science)                        Science
# 70            23                 Bachelor               Computer Science
# 71            23             Intermediate                Pre-Engineering
# 72            23                   Matric                        Science
#
#                                           institution  start_date    end_date  \
# 0                         Hamdard University, Karachi  2010-01-01  2014-12-31
# 1                 Tameer-e-Nau Public College, Quetta  2008-01-01  2009-12-31
# 2      Government high School  Killi Sheikhan, Quetta  2006-01-01  2007-12-31
# 3        The Islamia University, Bahawalpur, Pakistan  2010-01-01  2014-12-31
# 4            Superior College, Muzaffargarh, Pakistan  2006-08-01  2009-10-31
# ..                                                ...         ...         ...
# 68                Punjab Board of Technical Education  2007-01-01  2009-12-31
# 69                                   Rawalpindi Board  2003-01-01  2006-12-31
# 70  Federal Urdu University of Arts, Science and T...  2012-01-01  2016-12-31
# 71               F.G Boys Inter College Karachi Cantt  2009-01-01  2011-12-31
# 72     Ever Shine Govt. Boys Secondary School Karachi  2007-01-01  2009-12-31
#
#             grade                location  courses_count
# 0             3.1                 Karachi              0
# 1             74%                  Quetta              0
# 2             75%                  Quetta              0
# 3   CGPA 3.50/4.0    Bahawalpur, Pakistan              0
# 4      %AGE 76.00  Muzaffargarh, Pakistan              0
# ..            ...                     ...            ...
# 68           None                    None              0
# 69           None              Rawalpindi              0
# 70       3.79/4.0       Karachi, Pakistan             10
# 71           None       Karachi, Pakistan              0
# 72           None       Karachi, Pakistan              0
#
# [73 rows x 9 columns]

# %%
def clean_grade(grade):
    if pd.isna(grade) or grade == "":
        return None
    grade_str = str(grade).lower()
    if 'cgpa' in grade_str:
        cgpa_match = re.search(r'(\d+\.?\d*)', grade_str)
        if cgpa_match:
            return float(cgpa_match.group(1))
    elif "%" in grade_str:
        percent_match = re.search(r'(\d+)', grade_str)
        if percent_match:
            return float(percent_match.group(1))
    return grade

education['grade'] = education['grade'].apply(clean_grade)
education
# Out:
#     candidate_id                   degree                          field  \
# 0              1                 Bachelor  Telecommunication Engineering
# 1              1             Intermediate                Pre Engineering
# 2              1                   Matric
# 3              2                 Bachelor    Computer System Engineering
# 4              2             Intermediate                Pre-Engineering
# ..           ...                      ...                            ...
# 68            22       D.A.E (Electrical)                     Electrical
# 69            22  Matriculation (Science)                        Science
# 70            23                 Bachelor               Computer Science
# 71            23             Intermediate                Pre-Engineering
# 72            23                   Matric                        Science
#
#                                           institution  start_date    end_date  \
# 0                         Hamdard University, Karachi  2010-01-01  2014-12-31
# 1                 Tameer-e-Nau Public College, Quetta  2008-01-01  2009-12-31
# 2      Government high School  Killi Sheikhan, Quetta  2006-01-01  2007-12-31
# 3        The Islamia University, Bahawalpur, Pakistan  2010-01-01  2014-12-31
# 4            Superior College, Muzaffargarh, Pakistan  2006-08-01  2009-10-31
# ..                                                ...         ...         ...
# 68                Punjab Board of Technical Education  2007-01-01  2009-12-31
# 69                                   Rawalpindi Board  2003-01-01  2006-12-31
# 70  Federal Urdu University of Arts, Science and T...  2012-01-01  2016-12-31
# 71               F.G Boys Inter College Karachi Cantt  2009-01-01  2011-12-31
# 72     Ever Shine Govt. Boys Secondary School Karachi  2007-01-01  2009-12-31
#
#        grade                location  courses_count
# 0        3.1                 Karachi              0
# 1       74.0                  Quetta              0
# 2       75.0                  Quetta              0
# 3        3.5    Bahawalpur, Pakistan              0
# 4       76.0  Muzaffargarh, Pakistan              0
# ..       ...                     ...            ...
# 68      None                    None              0
# 69      None              Rawalpindi              0
# 70  3.79/4.0       Karachi, Pakistan             10
# 71      None       Karachi, Pakistan              0
# 72      None       Karachi, Pakistan              0
#
# [73 rows x 9 columns]

# %%
#level_mappping

level_mapping = {
    'Phd' : 5,
    'Master': 4,
    'Bachelor': 3, 
    'Diploma': 2,
    'Intermediate': 1,
    'Matric': 0
}

education['level'] = education['degree'].map(level_mapping).fillna(0)

# %% [markdown]
# #### Data Cleaning done, Now finding derived calculations

# %%
def derived_fields(basic,skills,experience,education):
    total_exp = experience.groupby('candidate_id')['duration_yrs'].sum().reset_index()
    total_exp.columns = ['candidate_id','total_exp_yrs']
    
    # getting highest education level
    highest_edu = education.loc[education.groupby('candidate_id')['level'].idxmax()]
    highest_edu = highest_edu[['candidate_id','degree','level']]
    highest_edu.columns = ['candidate_id','highest_degree','level']
    
    #finding skill diversity per candidate
    skill_diversity = skills.groupby('candidate_id')['category'].nunique().reset_index()
    skill_diversity.columns = ['candidate_id','skill_diversity_score']
    
    #Merging all derived fields back to basic info df
    
    basic_enhanced = basic.merge(total_exp,on='candidate_id',how='left')
    basic_enhanced = basic_enhanced.merge(highest_edu,on='candidate_id',how='left')
    basic_enhanced = basic_enhanced.merge(skill_diversity,on='candidate_id',how='left')
    
    basic_enhanced['total_exp_yrs'] = basic_enhanced['total_exp_yrs'].fillna(0)
    basic_enhanced['skill_diversity_score'] = basic_enhanced['skill_diversity_score'].fillna(0)
    
    return basic_enhanced

basic_final = derived_fields(basic,skills_cleaned,experience,education)
basic_final
# Out:
#     candidate_id                                           filename  \
# 0              1  ADNAN AHMED - CV for Research Assistants - Lab...
# 1              2           Awais Anwar - CV for Lab Instructor.json
# 2              3          Ebad Ali - CV for Research Assistant.json
# 3              4  Faisal Nisar - CV for for Research Assistant.json
# 4              5        Faisal Shahzad - CV for Lab Instructor.json
# 5              6  Faizan Asghar - CV for Research Assistant - La...
# 6              7     Ghulam Jaffar - CV for Research Assistant.json
# 7              8  Habib Ur Rahman - CV for Lab Instructor - Rese...
# 8              9        Hafiz Ali Raja - CV for Lab Instructor.json
# 9             10       Haris Ahmed - CV for Research Assistant.json
# 10            11  Hitesh Kumar - Resume for Research Assistants ...
# 11            12  Jawad Ahmed Bhutta - CV for Lab Instructor - R...
# 12            13    Muhammad Azmi Umer - CV for Lab Instructor.json
# 13            14  Muhammad Omaid Sheikh - CV for for Lab Instruc...
# 14            15  Muhammad Tayyab Yaqoob - CV for Lab Engineer.json
# 15            16  SAAD HASSAN - CV for Research Assistants - Lab...
# 16            17  Saad Hassan Khan - CV for Research Assistant (...
# 17            18       Sana Fatima - CV for Research Assistant.json
# 18            19      Shawana Khan - CV for Lab Instructor (1).json
# 19            20           Umair Ahmed - CV for Lab Instructor.json
# 20            21            Urooj Sheikh - CV for Lab Engineer.json
# 21            22           Waqas Ahmed - CV for Lab Instructor.json
# 22            23  Zohaib Khan - CV for Research Assistant - Lab ...
#
#                            full_name  \
# 0                        ADNAN AHMED
# 1                        Awaiz Anwar
# 2                           Ebad Ali
# 3            Hafiz Muhammad Ali Raja
# 4                     Faisal Shahzad
# 5                      Faizan Asghar
# 6   Ghulam Jaffar Research Assistant
# 7                    Habib Ur Rahman
# 8            Hafiz Muhammad Ali Raja
# 9                        Haris Ahmed
# 10                    HIT ESH KUMA R
# 11                Jawad Ahmed Bhutta
# 12                Muhammad Azmi Umer
# 13             MOHAMMAD UMAID SHEIKH
# 14      Engr. Muhammad Tayyab Yaqoob
# 15                       Saad Hassan
# 16                  SAAD HASSAN KHAN
# 17                       SANA FATIMA
# 18                      SHAWANA KHAN
# 19                       Umair Ahmed
# 20                      UROOJ SHEIKH
# 21                       Waqas Ahmed
# 22                       Zohaib Khan
#
#                                       current_title  \
# 0
# 1
# 2
# 3                  Lab Assistant/ Network Assistant
# 4
# 5
# 6
# 7
# 8                  Lab Assistant/ Network Assistant
# 9                                              None
# 10
# 11
# 12                                             None
# 13
# 14                            Lecturer/LAB Engineer
# 15
# 16                                             None
# 17                                   Jr. Instructor
# 18                                             None
# 19                                             None
# 20                              Electrical Engineer
# 21                             Electronics Engineer
# 22  Research Assistant/ Lab Instructor (Interested)
#
#                            email                     phone        city  \
# 0             dani_a4a@yahoo.com             +923458365922        None
# 1                                                     None        None
# 2             ebadalie@gmail.com             +923022689940     Karachi
# 3    alisherhaidri1984@gmail.com             +923216839854  Bahawalpur
# 4      faisalkhan00668@yahoo.com             +923137144006    Sargodha
# 5   Faizanasghar_sm1@hotmail.com             +923462662309     Karachi
# 6      ghulamjaffar110@gmail.com             +923448534083  Rawalpindi
# 7          Habib_tuf@hotmail.com             +923338967267     Sahiwal
# 8    alisherhaidri1984@gmail.com             +923216839854  Bahawalpur
# 9        Engrharris.iu@gmail.com             +923452781022     Karachi
# 10        hksolanki151@gmail.com             +923323714436     Karachi
# 11            jabhutta@gmail.com             +923333162772     Karachi
# 12    muhammadazmiumer@yahoo.com             +923312607116     Karachi
# 13            umaidned@gmail.com             +923242748533     Karachi
# 14         bu_tayyab@hotmail.com             +923212986106     Karachi
# 15          fadi_hitec@yahoo.com             +923421560619   Islamabad
# 16         Saadhassan@live.co.uk             +923364214764      Quetta
# 17             fzee_03@yahoo.com             +923343581384     Karachi
# 18      Shawana_khan24@yahoo.com             +923458318343      Quetta
# 19      Umair_ahmed403@yahoo.com             +923322190191     Karachi
# 20    scorp_sheikh11@hotmail.com             +923323453882        None
# 21            waqas638@gmail.com  +92345549402603125385028  Rawalpindi
# 22           me_zohaib@ymail.com             +923341251568     Karachi
#
#      country linkedin github  \
# 0
# 1   Pakistan
# 2   Pakistan     None   None
# 3   Pakistan     None   None
# 4       None
# 5   Pakistan
# 6   Pakistan     None   None
# 7   Pakistan
# 8   Pakistan     None   None
# 9   Pakistan     None   None
# 10  Pakistan     None   None
# 11  Pakistan
# 12  Pakistan     None   None
# 13  Pakistan     None   None
# 14  Pakistan
# 15  Pakistan
# 16  Pakistan     None   None
# 17  Pakistan     None   None
# 18  Pakistan     None   None
# 19      None     None   None
# 20      None     None   None
# 21  Pakistan     None   None
# 22  Pakistan     None   None
#
#                                               summary  total_skills  \
# 0   To join a dedicated and professional team in t...             7
# 1   Being a committed team player, want to be a pa...             4
# 2                                                None            10
# 3   To become a better & better IT resource with a...             6
# 4   I am young mature & enthusiastic individual be...            17
# 5   To acquire a career oriented position in a rep...             5
# 6   To seek a challenging and motivating career th...            16
# 7   To get the challenging position within the org...             6
# 8   To become a better & better IT resource with a...             6
# 9   Seeking a position in a Progressive and Reputa...             4
# 10  I’m an adaptable and efficient team player wit...             8
# 11  A well-presented, good all round performer who...            34
# 12  Looking for challenging and rewarding position...            12
# 13  Seeking full time opportunity to blend the the...            12
# 14                                                                7
# 15  To obtain a challenging position that allows m...            14
# 16  A position in a results-oriented organization ...             5
# 17  To utilize my skills for achieving the target ...            10
# 18  My aim is to get the better opportunities and ...            11
# 19  To use my knowledge and skills to better facil...             9
# 20  Seeking an Electrical Engineer position in pro...             5
# 21  A competent Electronics engineer with a compre...             7
# 22  Seeking challenging and pro-learning avenues w...             7
#
#     total_experience_years education_level               created_date  \
# 0                        0         Unknown 2025-07-26 06:15:32.320824
# 1                        0         Unknown 2025-07-26 06:15:32.323918
# 2                        0         Unknown 2025-07-26 06:15:32.327642
# 3                        0         Unknown 2025-07-26 06:15:32.331307
# 4                        0         Unknown 2025-07-26 06:15:32.336297
# 5                        0         Unknown 2025-07-26 06:15:32.339571
# 6                        0         Unknown 2025-07-26 06:15:32.341589
# 7                        0         Unknown 2025-07-26 06:15:32.341589
# 8                        0         Unknown 2025-07-26 06:15:32.351920
# 9                        0         Unknown 2025-07-26 06:15:32.358613
# 10                       0         Unknown 2025-07-26 06:15:32.358613
# 11                       0         Unknown 2025-07-26 06:15:32.358613
# 12                       0         Unknown 2025-07-26 06:15:32.366138
# 13                       0         Unknown 2025-07-26 06:15:32.366138
# 14                       0         Unknown 2025-07-26 06:15:32.374503
# 15                       0         Unknown 2025-07-26 06:15:32.379553
# 16                       0         Unknown 2025-07-26 06:15:32.382567
# 17                       0         Unknown 2025-07-26 06:15:32.382567
# 18                       0         Unknown 2025-07-26 06:15:32.382567
# 19                       0         Unknown 2025-07-26 06:15:32.390730
# 20                       0         Unknown 2025-07-26 06:15:32.390730
# 21                       0         Unknown 2025-07-26 06:15:32.390730
# 22                       0         Unknown 2025-07-26 06:15:32.390730
#
#     completeness_score  total_exp_yrs                   highest_degree  level  \
# 0                  100           0.00                         Bachelor    3.0
# 1                   75           0.11                         Bachelor    3.0
# 2                  100           2.00                              NaN    NaN
# 3                  100           0.00            BS (Computer Science)    0.0
# 4                  100           0.00                           MATRIC    0.0
# 5                  100           1.00                     Intermediate    1.0
# 6                  100          15.31                           Master    4.0
# 7                  100          14.48                           MS(CS)    0.0
# 8                  100           0.00            BS (Computer Science)    0.0
# 9                   75          11.64  BE-EE (Electronics Engineering)    0.0
# 10                 100           0.43                     Intermediate    1.0
# 11                 100           0.00  BE Computer Systems Engineering    0.0
# 12                  75           0.00                             M.S.    0.0
# 13                 100           0.98                     BS (CS & IT)    0.0
# 14                 100          15.15                             B.E.    0.0
# 15                 100           0.00              Bachelor of Science    0.0
# 16                  75           2.00      BS (Electrical Engineering)    0.0
# 17                 100          13.67    Bachelor of Engineering (B.E)    0.0
# 18                  75           1.00                  BS(Electronics)    0.0
# 19                  75          22.07           MS in Computer Science    0.0
# 20                 100           0.00                     Intermediate    1.0
# 21                 100           0.00    BEEE (Electronic Engineering)    0.0
# 22                 100          30.46                         Bachelor    3.0
#
#     skill_diversity_score
# 0                       2
# 1                       3
# 2                       3
# 3                       4
# 4                       3
# 5                       1
# 6                       6
# 7                       1
# 8                       4
# 9                       1
# 10                      1
# 11                      3
# 12                      3
# 13                      4
# 14                      3
# 15                      2
# 16                      2
# 17                      4
# 18                      2
# 19                      2
# 20                      1
# 21                      1
# 22                      2

# %% [markdown]
# ### Data Cleaning has been done

# %%
basic_final.to_csv("../data/cleaned/basic_info_cleaned.csv",index=False)
skills_cleaned.to_csv("../data/cleaned/skills_cleaned.csv",index=False)
experience.to_csv("../data/cleaned/experience_cleaned.csv",index=False)
education.to_csv("../data/cleaned/education_cleaned.csv",index=False)
